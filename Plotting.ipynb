# %% [markdown]
# # Plotting ejecta trajectories using cartopy

# %%
import cartopy
import matplotlib.path as mpath
import cartopy.crs as ccrs
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors as mcolors
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
trm_dict = {1 : "Moon Crust", 2 : "Moon Mantle", 3 : "Impactor Mantle", 4 : "Impactor Core"}
c_dict = {1: 'blue', 2: 'purple', 3: 'orange', 4: 'red'}

# %% [markdown]
# #### Plotting velocity = 10 km/s model with Azimuthal Equidistant projection:

# %%
df_final = pd.read_csv('full_tracer_mirror_v10.csv')


def main():
    fig = plt.figure(figsize=[10, 10])
    plt.tight_layout()
    ax1 = fig.add_subplot(1, 1, 1, projection=ccrs.AzimuthalEquidistant())
    fig.subplots_adjust(bottom=0.05, top=0.95,
                        left=0.04, right=0.95, wspace=0.02)

    # Limit the map to -60 degrees latitude and below.
    ax1.set_extent([-90,90 , 0, 90], ccrs.PlateCarree())
    ax1.set_global()
    ax1.gridlines()

    # Compute a circle in axes coordinates, which we can use as a boundary
    # for the map. We can pan/zoom as much as we like - the boundary will be
    # permanently circular.
    theta = np.linspace(0, 2*np.pi, 100)
    center, radius = [0.5, 0.5], 0.5
    verts = np.vstack([np.sin(theta), np.cos(theta)]).T
    circle = mpath.Path(verts * radius + center)

    
    launch_longs = np.array(df_final['Launch Longitude'])
    launch_lats = np.array(df_final['Launch Latitude'])
    land_longs = np.array(df_final['Landing Longitude'])
    land_lats = np.array(df_final['Landing Latitude'])
    trm = np.array(df_final['Tracer Material']).astype(np.int64)
    
    
#     key = 4
    for key in trm_dict:
        condition = np.where(trm == key)
    #         ax1.scatter(launch_longs[condition], launch_lats[condition], marker= 'x', s = 60, label = trm_dict[key],  transform = ccrs.PlateCarree())
        ax1.scatter(land_longs[condition], land_lats[condition], marker=".", s=20, c=c_dict[key], label = trm_dict[key], transform =  ccrs.PlateCarree())
        ax1.gridlines(draw_labels = True)


    plt.legend()
    #plt.savefig('Figures/material_map_v10_impactor.png' , dpi = 600, facecolor = 'w', bbox_inches = 'tight')


if __name__ == '__main__':
    main()

# %% [markdown]
# #### Plotting velocity = 15 km/s model with Azimuthal Equidistant projection:

# %%
df_final = pd.read_csv('full_tracer_mirror_v15.csv')


def main():
    fig = plt.figure(figsize=[10, 10])
    plt.tight_layout()
    ax1 = fig.add_subplot(1, 1, 1, projection=ccrs.AzimuthalEquidistant())
    fig.subplots_adjust(bottom=0.05, top=0.95,
                        left=0.04, right=0.95, wspace=0.02)

    # Limit the map to -60 degrees latitude and below.
    ax1.set_extent([-90,90 , 0, 90], ccrs.AzimuthalEquidistant())
    ax1.set_global()
    ax1.gridlines()

    # Compute a circle in axes coordinates, which we can use as a boundary
    # for the map. We can pan/zoom as much as we like - the boundary will be
    # permanently circular.
    theta = np.linspace(0, 2*np.pi, 100)
    center, radius = [0.5, 0.5], 0.5
    verts = np.vstack([np.sin(theta), np.cos(theta)]).T
    circle = mpath.Path(verts * radius + center)

    
    launch_longs = np.array(df_final['Launch Longitude'])
    launch_lats = np.array(df_final['Launch Latitude'])
    land_longs = np.array(df_final['Landing Longitude'])
    land_lats = np.array(df_final['Landing Latitude'])
    trm = np.array(df_final['Tracer Material']).astype(np.int64)
    
    
#     key = 2
    for key in trm_dict:
        condition = np.where(trm == key)
    #         ax1.scatter(launch_longs[condition], launch_lats[condition], marker= 'x', s = 60, label = trm_dict[key],  transform = ccrs.PlateCarree())
        ax1.scatter(land_longs[condition], land_lats[condition], marker=".", s=20, c=c_dict[key], label = trm_dict[key], transform =  ccrs.PlateCarree())
        ax1.gridlines(draw_labels = True)


    plt.legend()
    #plt.savefig('Figures/material_map_v15_azimuth.png' , dpi = 600, facecolor = 'w', bbox_inches = 'tight')


if __name__ == '__main__':
    main()

# %% [markdown]
# #### Plotting velocity = 10 km/s model with Mollweide projection:

# %%
df_final = pd.read_csv('csv_files/full_tracer_v15cold_mirror.csv')
def main():
    fig = plt.figure(figsize=[14, 14])
    plt.tight_layout()
    ax1 = fig.add_subplot(1, 1, 1, projection=ccrs.Mollweide())
    fig.subplots_adjust(bottom=0.05, top=0.95,
                        left=0.04, right=0.95, wspace=0.02)

    # Limit the map to -60 degrees latitude and below.
    ax1.set_extent([-90,90 , 0, 90], ccrs.PlateCarree())
    ax1.set_global()
    ax1.gridlines()

    # Compute a circle in axes coordinates, which we can use as a boundary
    # for the map. We can pan/zoom as much as we like - the boundary will be
    # permanently circular.
    theta = np.linspace(0, 2*np.pi, 100)
    center, radius = [0.5, 0.5], 0.5
    verts = np.vstack([np.sin(theta), np.cos(theta)]).T
    circle = mpath.Path(verts * radius + center)

    
    launch_longs = np.array(df_final['Launch Longitude'])
    launch_lats = np.array(df_final['Launch Latitude'])
    land_longs = np.array(df_final['Landing Longitude'])
    land_lats = np.array(df_final['Landing Latitude'])
    trm = np.array(df_final['Tracer Material']).astype(np.int64)
    
    
#     key = 2
    for key in trm_dict:
        condition = np.where(trm == key)
    #         ax1.scatter(launch_longs[condition], launch_lats[condition], marker= 'x', s = 60, label = trm_dict[key],  transform = ccrs.PlateCarree())
        ax1.scatter(land_longs[condition], land_lats[condition], marker=".", s=20, c=c_dict[key], label = trm_dict[key], transform =  ccrs.PlateCarree())
        ax1.gridlines(draw_labels = True)


    plt.legend()
    plt.savefig('Figures/material_map_v15cold_impactor.png' , dpi = 600, facecolor = 'w', bbox_inches = 'tight')


if __name__ == '__main__':
    main()

# %% [markdown]
# #### Plotting velocity = 15 km/s model with Mollweide projection (cold) :

# %%
df_final = pd.read_csv('csv_files/full_tracer_v15cold_mirror.csv')


def main():
    fig = plt.figure(figsize=[14, ])
    plt.tight_layout()
    ax1 = fig.add_subplot(1, 2, 1, projection=ccrs.Mollweide())

    fig.subplots_adjust(bottom=0.05, top=0.95,
                        left=0.04, right=0.95, wspace=0.02)

    # Limit the map to -60 degrees latitude and below.
    ax1.set_extent([-90, 90, 0, 90], ccrs.PlateCarree())
    ax1.gridlines()
    ax1.set_global()

    # Compute a circle in axes coordinates, which we can use as a boundary
    # for the map. We can pan/zoom as much as we like - the boundary will be
    # permanently circular.
    theta = np.linspace(0, 2*np.pi, 100)
    center, radius = [0.5, 0.5], 0.5
    verts = np.vstack([np.sin(theta), np.cos(theta)]).T
    circle = mpath.Path(verts * radius + center)

    
    launch_longs = np.array(df_final['Launch Longitude'])
    launch_lats = np.array(df_final['Launch Latitude'])
    land_longs = np.array(df_final['Landing Longitude'])
    land_lats = np.array(df_final['Landing Latitude'])
    v_r = np.array(df_final['Resultant Velocity'])
    
    # ax1.scatter(launch_longs[condition], launch_lats[condition], marker= 'x', s = 60, c = trm,  transform = ccrs.PlateCarree())
#     plot = ax1.scatter(land_longs, land_lats, marker = 'x', s = 60, c=v_r, cmap='viridis', transform =  ccrs.PlateCarree(), vmin = 0, vmax= 2.38)
    plot = ax1.scatter(land_longs, land_lats, marker=".", s=20, c=v_r, cmap='viridis', transform =  ccrs.PlateCarree(), vmin = 0, vmax= 2.38)
    ax1.gridlines(draw_labels = True)
    
    # colorbar 
#     norm, m = velo_range(min_v = 0, max_v = 2.38)
    
    cbar = plt.colorbar(plot, label='velocity (km/s)', aspect=5, cax = fig.add_axes([0.52, 0.35, 0.02, 0.3]))
    
    plt.savefig('Figures/velocity_map.png' , dpi = 600, facecolor = 'w', bbox_inches = 'tight')


if __name__ == '__main__':
    main()

# %%
df_final = pd.read_csv('csv_files/full_tracer_v15cold_mirror.csv')
def main():
    fig = plt.figure(figsize=[14, 14])
    plt.tight_layout()
    ax1 = fig.add_subplot(1, 1, 1, projection=ccrs.Mollweide())
    fig.subplots_adjust(bottom=0.05, top=0.95,
                        left=0.04, right=0.95, wspace=0.02)

    # Limit the map to -60 degrees latitude and below.
    ax1.set_extent([-90,90 , 0, 90], ccrs.PlateCarree())
    ax1.set_global()
    ax1.gridlines()

    # Compute a circle in axes coordinates, which we can use as a boundary
    # for the map. We can pan/zoom as much as we like - the boundary will be
    # permanently circular.
    theta = np.linspace(0, 2*np.pi, 100)
    center, radius = [0.5, 0.5], 0.5
    verts = np.vstack([np.sin(theta), np.cos(theta)]).T
    circle = mpath.Path(verts * radius + center)

    
    launch_longs = np.array(df_final['Launch Longitude'])
    launch_lats = np.array(df_final['Launch Latitude'])
    land_longs = np.array(df_final['Landing Longitude'])
    land_lats = np.array(df_final['Landing Latitude'])
    v_r = np.array(df_final['Resultant Velocity'])
    
    
    

    #         ax1.scatter(launch_longs[condition], launch_lats[condition], marker= 'x', s = 60, label = trm_dict[key],  transform = ccrs.PlateCarree())
    plot = ax1.scatter(land_longs, land_lats, marker=".", s=20, c=v_r, cmap='viridis', transform =  ccrs.PlateCarree(), vmin = 0, vmax= 2.38)
    ax1.gridlines(draw_labels = True)


    cbar = plt.colorbar(plot, label='velocity (km/s)', aspect=5, cax = fig.add_axes([1.0, 0.3, 0.02, 0.4]))
    plt.savefig('Figures/velocity_map.png' , dpi = 600, facecolor = 'w', bbox_inches = 'tight')


if __name__ == '__main__':
    main()
